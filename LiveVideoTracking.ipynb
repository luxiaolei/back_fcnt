# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
"""
Main script for FCNT tracker. 
"""

# Import custom class and functions
from inputproducer import LiveInput
from tracker import TrackerContour
from vgg16 import Vgg16
from sgnet import GNet, SNet
from utils import img_with_bbox, IOU_eval, select_fms

import cv2
import numpy as np 
import tensorflow as tf
import matplotlib.pylab as plt

from scipy.misc import imresize
from subprocess import call
import sys
import os
import time

tf.app.flags.DEFINE_integer('iter_epoch_sg', 5,
                          """Number of epoches for trainning"""
                          """SGnet works""")
tf.app.flags.DEFINE_integer('batch_size', 20,
                          """Batch size for SGNet trainning"""
                          """SGnet works""")
tf.app.flags.DEFINE_integer('n_samples_per_batch', 5000,
                          """Number of samples per batch for trainning"""
                          """SGnet works""")
tf.app.flags.DEFINE_integer('iter_max', 1349,
							"""Max iter times through imgs""")
tf.app.flags.DEFINE_integer('sel_num', 354,
                          """Number of feature maps selected.""")
tf.app.flags.DEFINE_string('model_name', 'first_LiveFaceXL',
						"""true for train, false for eval""")
FLAGS = tf.app.flags.FLAGS

## Define varies pathes
DATA_ROOT = 'data/Car1'
PRE_ROOT = os.path.join(DATA_ROOT, 'img_loc')
IMG_PATH = os.path.join(DATA_ROOT, 'img')
GT_PATH = os.path.join(DATA_ROOT, 'groundtruth_rect.txt')
VGG_WEIGHTS_PATH = 'vgg16_weights.npz'


#if not os.path.isdir(PRE_ROOT):
#    os.mkdir(PRE_ROOT)


TB_SUMMARY = os.path.join('tb_summary', FLAGS.model_name)
if not os.path.isdir('tb_summary'):
    os.mkdir('tb_summary')
if not os.path.isdir(TB_SUMMARY):
    os.mkdir(TB_SUMMARY)

CKPT_PATH = 'checkpoint'
if not os.path.isdir(CKPT_PATH):
    os.mkdir(CKPT_PATH)

model_name = FLAGS.model_name+'.ckpt'
CKPT_MODEL = os.path.join(CKPT_PATH, model_name)


def init_vgg(sess, roi_t0=None, predict=True):
    """
    Initialize a tf.Session and a vgg16 graph. Followed
    by forwarding the vgg net once to predict top5 class labels
    for image generated in the first frame.

    Args:
        roi_t0: np.ndarray with shape (28x28x3), extracted roi in the first frame.
    Returns:
        sess: tf.Session object.
        vgg: Vgg16 class instance.
    """
    print('Classify it with a pre-trained Vgg16 model.')
    t_start = time.time()

    #sess.run(tf.initialize_all_variables())
    vgg = Vgg16(VGG_WEIGHTS_PATH, sess)
    if predict and roi_t0 is not None:
        vgg.print_prob(roi_t0, sess)
    print('Forwarding the vgg net cost : %.2f s'%(time.time() - t_start))
    return vgg

def gen_sel_maps(sess, roi, vgg, idx_c4, idx_c5):
    """Returns selected c4 and c5 maps"""
    if len(roi.shape) == 3: roi = [roi]
    fd = {vgg.imgs : roi}
    c4_arr, c5_arr = sess.run([vgg.conv4_3_norm, vgg.conv5_3_norm], feed_dict=fd)
    c4_maps = c4_arr[...,idx_c4]
    c5_maps = c5_arr[...,idx_c5]
    return c4_maps, c5_maps


def train_SGNets(sess, img, gt, vgg, snet, gnet, inputProducer, idx_c4, idx_c5):
    """
    Train SGnets' variables by minimizing a composite L2 regression losses.

    Args:
        sess: tf.Session object.
        vgg: Vgg16 class instance.
        snet: SNet class instance.
        gnet:  GNet class instance.
        inputProducer: InputProducer class instance.
    """
    gnet.params['wd'] = 0.5
    loss = gnet.loss + snet.loss
    tf.scalar_summary('loss', loss)
    writer = tf.train.SummaryWriter(TB_SUMMARY, sess.graph)
    
    vars_train = gnet.variables + snet.variables

    # Backprop using SGD and updates vgg variables and sgnets variables
    global_step = tf.Variable(0, trainable=False)
    lr_exp = tf.train.exponential_decay(
            0.25, # Initial learning rate 
            global_step, 
            1000, # Decay steps 
            0.8, # Decay rate 
            name='sg_lr')

    tf.scalar_summary('Learning rate', lr_exp)
    optimizer = tf.train.GradientDescentOptimizer(lr_exp)
    train_op = optimizer.minimize(loss, var_list= vars_train, global_step=global_step)
    merged = tf.merge_all_summaries()
    
    print('Generating batches from img size:%s  for trainning.'%str(img.shape))
    sample_batches, target_batches = inputProducer.gen_batches(img, gt, n_samples=FLAGS.n_samples_per_batch, batch_sz=FLAGS.batch_size, pos_ratio=0.5, scale_factors=np.arange(0.5, 5., 0.2)) #np.array([1]))#
    print('Start training the SGNets........ for %s epoches'%FLAGS.iter_epoch_sg)
    saver = tf.train.Saver()
    step = 1
    loss_list = []
    for ep in range(FLAGS.iter_epoch_sg):
        print('Total batches in each epoch: ', len(sample_batches))
        for roi, target in zip(sample_batches, target_batches):
            #roi[roi>0] = 1 # neglect gaussian..set to 1 for target arear
            
            t = time.time()
            c4_maps, c5_maps = gen_sel_maps(sess, roi, vgg, idx_c4, idx_c5)
            
            fd = {gnet.input_maps: c5_maps, gnet.gt_M: target, 
                  snet.input_maps: c4_maps, snet.gt_M: target}
            
            # Initialization 
            if step == 1:
                loss_g = 10
                init_s = 0
                while loss_g > 1.2:
                    init_s += 1
                    sess.run(tf.initialize_variables(gnet.variables))
                    loss_g = sess.run(gnet.loss, feed_dict=fd)
                    print('Initial Gnet Loss: ', loss_g, 'In steps: ', init_s)
                sess.run(tf.initialize_variables(snet.variables + [global_step]))
                
            
            pre_M_g, l, _, lr = sess.run([gnet.pre_M, loss, train_op, lr_exp], feed_dict=fd)
            
            loss_list += [l]
            if l <= 0.1:
                print('break learning!')
                break
            if step % 20 == 0:
                
                loss_ac = np.diff(np.diff(loss_list[-19:]))
                loss_ac_summary = tf.scalar_summary('Loss acceleration', loss_ac.mean())
                
                
                summary_img_g = tf.image_summary('pre_M', 
                                                 np.repeat(pre_M_g[...,np.newaxis], 3, axis=-1), name='GMap')

                summary, img_summary_g, ac_loss_summary = sess.run([merged, summary_img_g, loss_ac_summary], feed_dict=fd)

                writer.add_summary(summary, global_step=step)
                writer.add_summary(img_summary_g, global_step=step)
                writer.add_summary(ac_loss_summary, global_step=step)
                
                loss_std = np.std(loss_list[-19:])
                if loss_std <= 0.007:
                    
                    print('Stop learning??! Last 10 batches Loss Std: ', loss_std)
                    #break

            #if step % 20 == 0:
                print('Epoch: ', ep+1, 'Step: ', (ep+1)*step, 'Loss : %.2f'%l, \
                    'Speed: %.2f second/batch'%(time.time()-t), 'Lr: ', lr)
                #saver.save(sess, CKPT_MODEL)
            step += 1



print('Reading the first image...')
t_start = time.time()
## Instantiate inputProducer and retrive the first img
# with associated ground truth. 
inputProducer = LiveInput()
# Out:
# Reading the first image...

# %%
# import the necessary packages
#import argparse
import cv2

# initialize the list of reference points and boolean indicating
# whether cropping is being performed or not
refPt = []
cropping = False

def click_and_crop(event, x, y, flags, param):
    # grab references to the global variables
    global refPt, cropping

    # if the left mouse button was clicked, record the starting
    # (x, y) coordinates and indicate that cropping is being
    # performed
    if event == cv2.EVENT_LBUTTONDOWN:
        refPt = [(x, y)]
        #cropping = True

    # check to see if the left mouse button was released
    elif event == cv2.EVENT_LBUTTONUP:
        # record the ending (x, y) coordinates and indicate that
        # the cropping operation is finished
        refPt.append((x, y))
        #cropping = False

        # draw a rectangle around the region of interest
        #cv2.rectangle(image, refPt[0], refPt[1], (0, 255, 0), 2)
        #cv2.imshow("image", image)

# %%
def refPt_2_gt(refPt):
    p1, p2 = refPt
    x1, y1 = p1
    x2, y2 = p2
    w = x2 - x1
    h = y2 - y1
    return (x1, y1, w, h)

# %%
tracker = TrackerContour()
inputProducer.roi_params['roi_scale'] = 2.5


cap = cv2.VideoCapture(0)
cv2.namedWindow("image")
cv2.setMouseCallback("image", click_and_crop)


sess = tf.Session()

snet = SNet('SNet', FLAGS.sel_num)
gnet = GNet('GNet', FLAGS.sel_num)
saver = tf.train.Saver()
saved_ckpt = os.path.join('checkpoint', FLAGS.model_name.split('_')[-1]+'.ckpt')
if os.path.exists(saved_ckpt):
    print('Found saved model %s, restoring! '%saved_ckpt)
    saver.restore(sess, saved_ckpt)
    TrackReady = True
else: 
    TrackReady = False
    
PosReady = False

while(cap.isOpened()):
    # Capture frame-by-frame
    ret, image = cap.read()

    # load the image, clone it, and setup the mouse callback function
    clone = image.copy()
    
    key = cv2.waitKey(1) & 0xFF
    # keep looping until the 'q' key is pressed

    

    # if there are two reference points, then crop the region of interest
    # from teh image and display it
    if len(refPt) == 2 and key==ord("c"):      
        roi = clone[refPt[0][1]:refPt[1][1], refPt[0][0]:refPt[1][0]]
        cv2.imshow("CroppedROI", roi)

        gt = refPt_2_gt(refPt)
        img = image
        print(gt, 'gt in first!')
        
        inputProducer.save_fist_roi_mean(img, gt)


    # train
    
    if key == ord('t'):
        roi_t0, _, rz_factor = inputProducer.extract_roi(img, gt)
        
        # Predicts the first img.
        vgg = init_vgg(sess, roi_t0)
        fd = {vgg.imgs: [roi_t0]}
        gt_M = inputProducer.gen_mask((28,28)) # rank2 array


        ## At t=0. Train S and G Nets 
        # Instainate SGNets with conv tensors and training.
        # 1. feature maps selection
        # 2. Train G and S networks.
        idx_c4 = select_fms(sess, vgg.conv4_3_norm, gt, rz_factor, fd, FLAGS.sel_num)
        idx_c5 = select_fms(sess, vgg.conv5_3_norm, gt, rz_factor, fd, FLAGS.sel_num)
        
        if not TrackReady:
            train_SGNets(sess, img, gt, vgg, snet, gnet, inputProducer, idx_c4, idx_c5)
            saver.save(sess, saved_ckpt)
            TrackReady = True
    
    
    # Records the first position
    if key == ord('s'):
        gt_last = refPt_2_gt(refPt)
        print(gt_last, 'gt in start~!')
        PosReady = True
        
        
    # Start tracking
    if PosReady and TrackReady:
        img = image.copy()
        #img = inputProducer.Ajust_brighteness(img, gt_last)
        roi, _, rz_factor = inputProducer.extract_roi(img, gt_last)

        # @inputproducer, remove low level pixel
        noise_value = 10#np.argmax(hist)*0.1
        roi[roi<noise_value] = roi.mean()
        
        ## Perform Target localiation predicted by GNet
        # Get heat map predicted by GNet
        c4_maps, c5_maps = gen_sel_maps(sess, roi, vgg, idx_c4, idx_c5)
        fd = {gnet.input_maps: c5_maps, snet.input_maps: c4_maps}
        pre_M_g, pre_M_s = sess.run([gnet.pre_M, snet.pre_M], feed_dict=fd)

        pre_M = tracker.preporcess_heatmaps(pre_M_g, pre_M_s, resize=(224,224))
        pre_loc = tracker.predict_location(pre_M,gt_last,rz_factor,threshold=np.arange(0.3, 0.9, 0.05))
        
        gt_last = pre_loc
        x,y,w,h = pre_loc
        print('pre_loc', pre_loc)
        cv2.rectangle(image,(x,y),(x+w,y+h),(225,0,0),2)
        font = cv2.FONT_HERSHEY_SIMPLEX
        cv2.putText(image, 'conf score: %s'%1,(5,20), font, 0.6,(255,0,0),1,cv2.LINE_AA)
        
        cv2.imshow("pre_M_g", pre_M_g)
        cv2.imshow("pre_M_s", pre_M_s)
        cv2.imshow("pre_M_g", pre_M_g)
        cv2.imshow("ROI", roi)
        # Finetune SNet
        
        print('Tracking done in step: %s'%tracker.step)
        
        
    cv2.imshow("image", image)

# close all open windows
cv2.destroyAllWindows()
# Out:
# Found saved model checkpoint/LiveFaceXL.ckpt, restoring!
# (259, 168, 98, 136) gt in first!
# /home/xlws/repos/FCNT_bak/inputproducer.py:110: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   roi = convas[cy-half:cy+half, cx-half:cx+half, :]
# Classify it with a pre-trained Vgg16 model.
# cardigan 0.707232
# fur coat 0.0585385
# stole 0.0426091
# wool, woolen, woollen 0.0249354
# trench coat 0.0167647
# Forwarding the vgg net cost : 4.90 s
# Classify it with a pre-trained Vgg16 model.
# /home/xlws/repos/FCNT_bak/utils.py:81: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   conf_i = roi[c-h_half:c+h_half, c-w_half:c+w_half].sum()
# cardigan 0.707232
# fur coat 0.0585385
# stole 0.0426091
# wool, woolen, woollen 0.0249354
# trench coat 0.0167647
# Forwarding the vgg net cost : 11.15 s
# (259, 168, 98, 136) gt in start~!
# pre_loc [271, 173, 81, 104]
# Tracking done in step: 1
# pre_loc [275, 192, 91, 117]
# Tracking done in step: 2
# pre_loc [272, 182, 109, 123]
# Tracking done in step: 3
# pre_loc [267, 176, 113, 128]
# Tracking done in step: 4
# pre_loc [268, 172, 125, 132]
# Tracking done in step: 5
# /home/xlws/repos/FCNT_bak/tracker.py:35: RuntimeWarning: divide by zero encountered in true_divide
#   scores = scores_dis / arear_list
# pre_loc [262, 172, 131, 135]
# Tracking done in step: 6
# pre_loc [263, 170, 141, 138]
# Tracking done in step: 7
# pre_loc [255, 166, 139, 141]
# Tracking done in step: 8
# pre_loc [257, 167, 136, 132]
# Tracking done in step: 9
# pre_loc [257, 172, 135, 132]
# Tracking done in step: 10
# pre_loc [257, 170, 132, 129]
# Tracking done in step: 11
# pre_loc [257, 175, 129, 131]
# Tracking done in step: 12
# pre_loc [259, 171, 128, 132]
# Tracking done in step: 13
# pre_loc [259, 171, 128, 131]
# Tracking done in step: 14
# pre_loc [259, 173, 129, 129]
# Tracking done in step: 15
# pre_loc [259, 173, 126, 130]
# Tracking done in step: 16
# pre_loc [259, 173, 125, 133]
# Tracking done in step: 17
# pre_loc [263, 171, 127, 130]
# Tracking done in step: 18
# pre_loc [260, 173, 124, 133]
# Tracking done in step: 19
# pre_loc [262, 170, 127, 128]
# Tracking done in step: 20
# pre_loc [259, 175, 115, 125]
# Tracking done in step: 21
# pre_loc [263, 178, 107, 126]
# Tracking done in step: 22
# pre_loc [269, 178, 107, 121]
# Tracking done in step: 23
# pre_loc [266, 182, 99, 119]
# Tracking done in step: 24
# pre_loc [269, 182, 100, 120]
# Tracking done in step: 25
# pre_loc [267, 182, 99, 119]
# Tracking done in step: 26
# pre_loc [268, 181, 100, 122]
# Tracking done in step: 27
# pre_loc [269, 178, 108, 128]
# Tracking done in step: 28
# pre_loc [271, 173, 124, 130]
# Tracking done in step: 29
# pre_loc [261, 171, 128, 138]
# Tracking done in step: 30
# pre_loc [261, 166, 135, 135]
# Tracking done in step: 31
# pre_loc [256, 172, 135, 132]
# Tracking done in step: 32
# pre_loc [257, 171, 132, 130]
# Tracking done in step: 33
# pre_loc [259, 173, 128, 131]
# Tracking done in step: 34
# pre_loc [258, 173, 120, 126]
# Tracking done in step: 35
# pre_loc [261, 179, 110, 130]
# Tracking done in step: 36
# pre_loc [266, 173, 115, 125]
# Tracking done in step: 37
# pre_loc [264, 179, 114, 129]
# Tracking done in step: 38
# pre_loc [263, 175, 116, 122]
# Tracking done in step: 39
# pre_loc [260, 180, 107, 127]
# Tracking done in step: 40
# pre_loc [266, 175, 111, 124]
# Tracking done in step: 41
# pre_loc [265, 181, 109, 125]
# Tracking done in step: 42
# pre_loc [265, 176, 112, 125]
# Tracking done in step: 43
# pre_loc [265, 179, 111, 123]
# Tracking done in step: 44
# pre_loc [265, 180, 106, 122]
# Tracking done in step: 45
# pre_loc [264, 181, 99, 119]
# Tracking done in step: 46
# pre_loc [270, 182, 100, 120]
# Tracking done in step: 47
# pre_loc [268, 180, 99, 117]
# Tracking done in step: 48
# pre_loc [266, 188, 96, 110]
# Tracking done in step: 49
# pre_loc [268, 189, 90, 112]
# Tracking done in step: 50
# pre_loc [273, 186, 95, 120]
# Tracking done in step: 51
# pre_loc [270, 181, 107, 121]
# Tracking done in step: 52
# pre_loc [268, 180, 105, 122]
# Tracking done in step: 53
# pre_loc [265, 182, 101, 118]
# Tracking done in step: 54
# pre_loc [268, 183, 101, 120]
# Tracking done in step: 55
# pre_loc [269, 181, 101, 120]
# Tracking done in step: 56
# pre_loc [267, 181, 99, 119]
# Tracking done in step: 57
# pre_loc [268, 184, 100, 117]
# Tracking done in step: 58
# pre_loc [268, 184, 101, 118]
# Tracking done in step: 59
# pre_loc [268, 182, 101, 118]
# Tracking done in step: 60
# pre_loc [268, 183, 102, 118]
# Tracking done in step: 61
# pre_loc [266, 184, 101, 119]
# Tracking done in step: 62
# pre_loc [269, 180, 103, 125]
# Tracking done in step: 63
# pre_loc [271, 175, 121, 130]
# Tracking done in step: 64
# pre_loc [265, 169, 127, 137]
# Tracking done in step: 65
# pre_loc [264, 170, 135, 131]
# Tracking done in step: 66
# pre_loc [257, 173, 133, 135]
# Tracking done in step: 67
# pre_loc [257, 168, 136, 132]
# Tracking done in step: 68
# pre_loc [256, 171, 135, 129]
# Tracking done in step: 69
# pre_loc [259, 173, 129, 130]
# Tracking done in step: 70
# pre_loc [257, 173, 118, 124]
# Tracking done in step: 71
# pre_loc [260, 179, 109, 124]
# Tracking done in step: 72
# pre_loc [268, 178, 107, 123]
# Tracking done in step: 73
# pre_loc [265, 180, 103, 117]
# Tracking done in step: 74
# pre_loc [267, 185, 101, 122]
# Tracking done in step: 75
# pre_loc [268, 182, 100, 119]
# Tracking done in step: 76
# pre_loc [267, 184, 101, 118]
# Tracking done in step: 77
# pre_loc [268, 184, 102, 122]
# Tracking done in step: 78
# pre_loc [267, 179, 101, 119]
# Tracking done in step: 79
# pre_loc [268, 183, 101, 120]
# Tracking done in step: 80
# pre_loc [268, 179, 103, 121]
# Tracking done in step: 81
# pre_loc [268, 181, 110, 129]
# Tracking done in step: 82
# pre_loc [265, 173, 120, 126]
# Tracking done in step: 83
# pre_loc [262, 175, 113, 123]
# Tracking done in step: 84
# pre_loc [262, 182, 109, 129]
# Tracking done in step: 85
# pre_loc [267, 176, 116, 126]
# Tracking done in step: 86
# pre_loc [264, 175, 113, 124]
# Tracking done in step: 87
# pre_loc [264, 179, 112, 127]
# Tracking done in step: 88
# pre_loc [265, 176, 112, 122]
# Tracking done in step: 89
# pre_loc [262, 181, 103, 119]
# Tracking done in step: 90
# pre_loc [267, 183, 104, 118]
# Tracking done in step: 91
# pre_loc [263, 185, 101, 115]
# Tracking done in step: 92
# pre_loc [268, 186, 99, 118]
# Tracking done in step: 93
# pre_loc [270, 182, 105, 120]
# Tracking done in step: 94
# pre_loc [268, 181, 109, 124]
# Tracking done in step: 95
# pre_loc [265, 177, 112, 123]
# Tracking done in step: 96
# pre_loc [262, 179, 113, 125]
# Tracking done in step: 97
# pre_loc [264, 177, 111, 125]
# Tracking done in step: 98
# pre_loc [264, 176, 112, 129]
# Tracking done in step: 99
# pre_loc [267, 173, 125, 129]
# Tracking done in step: 100
# pre_loc [262, 174, 126, 132]
# Tracking done in step: 101
# pre_loc [260, 170, 129, 128]
# Tracking done in step: 102
# pre_loc [258, 174, 123, 129]
# Tracking done in step: 103
# pre_loc [261, 174, 122, 133]
# Tracking done in step: 104
# pre_loc [262, 171, 127, 127]
# Tracking done in step: 105
# pre_loc [259, 175, 118, 126]
# Tracking done in step: 106
# pre_loc [261, 178, 113, 124]
# Tracking done in step: 107
# pre_loc [264, 175, 112, 125]
# Tracking done in step: 108
# pre_loc [264, 177, 114, 125]
# Tracking done in step: 109
# pre_loc [262, 179, 108, 123]
# Tracking done in step: 110
# pre_loc [266, 179, 110, 125]
# Tracking done in step: 111
# pre_loc [267, 177, 111, 119]
# Tracking done in step: 112
# pre_loc [265, 181, 107, 120]
# Tracking done in step: 113
# pre_loc [265, 182, 99, 120]
# Tracking done in step: 114
# pre_loc [271, 179, 97, 116]
# Tracking done in step: 115
# pre_loc [270, 185, 99, 113]
# Tracking done in step: 116
# pre_loc [267, 188, 95, 109]
# Tracking done in step: 117
# pre_loc [271, 188, 93, 115]
# Tracking done in step: 118
# pre_loc [272, 184, 100, 117]
# Tracking done in step: 119
# pre_loc [270, 183, 100, 118]
# Tracking done in step: 120
# pre_loc [266, 183, 101, 115]
# Tracking done in step: 121
# pre_loc [268, 188, 102, 114]
# Tracking done in step: 122
# pre_loc [269, 187, 102, 117]
# Tracking done in step: 123
# pre_loc [270, 188, 110, 126]
# Tracking done in step: 124
# pre_loc [268, 177, 123, 130]
# Tracking done in step: 125
# pre_loc [265, 173, 127, 131]
# Tracking done in step: 126
# pre_loc [260, 173, 125, 133]
# Tracking done in step: 127
# pre_loc [262, 171, 128, 130]
# Tracking done in step: 128
# pre_loc [261, 173, 128, 133]
# Tracking done in step: 129
# pre_loc [256, 172, 127, 125]
# Tracking done in step: 130
# pre_loc [257, 179, 124, 135]
# Tracking done in step: 131
# pre_loc [259, 171, 133, 138]
# Tracking done in step: 132
# pre_loc [259, 167, 135, 132]
# Tracking done in step: 133
# pre_loc [256, 173, 133, 129]
# Tracking done in step: 134
# pre_loc [258, 173, 128, 131]
# Tracking done in step: 135
# pre_loc [259, 173, 128, 130]
# Tracking done in step: 136
# pre_loc [258, 173, 128, 131]
# Tracking done in step: 137
# pre_loc [259, 173, 128, 132]
# Tracking done in step: 138
# pre_loc [259, 171, 128, 129]
# Tracking done in step: 139
# pre_loc [259, 174, 127, 127]
# Tracking done in step: 140
# pre_loc [260, 175, 124, 129]
# Tracking done in step: 141
# pre_loc [260, 172, 127, 130]
# Tracking done in step: 142
# pre_loc [261, 173, 127, 130]
# Tracking done in step: 143
# pre_loc [258, 173, 125, 133]
# Tracking done in step: 144
# pre_loc [261, 172, 128, 131]
# Tracking done in step: 145
# pre_loc [260, 172, 129, 132]
# Tracking done in step: 146
# pre_loc [257, 170, 131, 129]
# Tracking done in step: 147
# pre_loc [257, 174, 126, 130]
# Tracking done in step: 148
# pre_loc [262, 173, 125, 131]
# Tracking done in step: 149
# pre_loc [260, 171, 128, 130]
# Tracking done in step: 150
# pre_loc [259, 173, 128, 128]
# Tracking done in step: 151
# pre_loc [259, 174, 128, 131]
# Tracking done in step: 152
# pre_loc [259, 171, 126, 129]
# Tracking done in step: 153
# pre_loc [261, 175, 126, 132]
# Tracking done in step: 154
# pre_loc [261, 170, 132, 129]
# Tracking done in step: 155
# pre_loc [260, 175, 134, 132]
# Tracking done in step: 156
# pre_loc [258, 171, 137, 132]
# Tracking done in step: 157
# pre_loc [256, 173, 140, 129]
# Tracking done in step: 158
# pre_loc [256, 173, 137, 129]
# Tracking done in step: 159
# pre_loc [256, 172, 126, 129]
# Tracking done in step: 160
# pre_loc [260, 177, 123, 133]
# Tracking done in step: 161
# pre_loc [262, 173, 128, 131]
# Tracking done in step: 162
# pre_loc [259, 173, 119, 128]
# Tracking done in step: 163
# pre_loc [262, 177, 115, 128]
# Tracking done in step: 164
# pre_loc [265, 176, 112, 124]
# Tracking done in step: 165
# pre_loc [263, 179, 102, 120]
# Tracking done in step: 166
# pre_loc [269, 182, 101, 116]
# Tracking done in step: 167
# pre_loc [267, 187, 93, 110]
# Tracking done in step: 168
# pre_loc [271, 192, 89, 106]
# Tracking done in step: 169
# pre_loc [273, 194, 81, 97]
# Tracking done in step: 170
# pre_loc [278, 206, 73, 87]
# Tracking done in step: 171
# pre_loc [283, 216, 63, 77]
# Tracking done in step: 172
# pre_loc [289, 227, 54, 68]
# Tracking done in step: 173
# pre_loc [297, 225, 50, 65]
# Tracking done in step: 174
# pre_loc [297, 228, 54, 73]
# Tracking done in step: 175
# pre_loc [294, 223, 56, 71]
# Tracking done in step: 176
# pre_loc [294, 225, 59, 75]
# Tracking done in step: 177
# pre_loc [292, 214, 63, 96]
# Tracking done in step: 178
# pre_loc [286, 196, 92, 118]
# Tracking done in step: 179
# pre_loc [274, 181, 114, 131]
# Tracking done in step: 180
# pre_loc [265, 172, 129, 138]
# Tracking done in step: 181
# pre_loc [264, 172, 145, 141]
# Tracking done in step: 182
# pre_loc [251, 167, 132, 132]
# Tracking done in step: 183
# pre_loc [257, 176, 128, 134]
# Tracking done in step: 184
# pre_loc [259, 173, 128, 131]
# Tracking done in step: 185
# pre_loc [259, 171, 128, 130]
# Tracking done in step: 186
# pre_loc [260, 174, 130, 131]
# Tracking done in step: 187
# pre_loc [259, 168, 132, 135]
# Tracking done in step: 188
# pre_loc [257, 171, 135, 130]
# Tracking done in step: 189
# pre_loc [257, 173, 133, 130]
# Tracking done in step: 190
# pre_loc [257, 171, 128, 130]
# Tracking done in step: 191
# pre_loc [259, 173, 127, 133]
# Tracking done in step: 192
# pre_loc [261, 171, 133, 130]
# Tracking done in step: 193
# pre_loc [261, 173, 136, 131]
# Tracking done in step: 194
# pre_loc [257, 173, 135, 130]
# Tracking done in step: 195
# pre_loc [256, 172, 133, 130]
# Tracking done in step: 196
# pre_loc [258, 172, 127, 128]
# Tracking done in step: 197
# pre_loc [262, 174, 125, 132]
# Tracking done in step: 198
# pre_loc [262, 170, 132, 131]
# Tracking done in step: 199
# pre_loc [261, 175, 131, 131]
# Tracking done in step: 200
# pre_loc [262, 169, 130, 132]
# Tracking done in step: 201
# pre_loc [261, 174, 128, 131]
# Tracking done in step: 202
# pre_loc [260, 171, 129, 133]
# Tracking done in step: 203
# pre_loc [260, 171, 133, 131]
# Tracking done in step: 204
# pre_loc [259, 173, 134, 130]
# Tracking done in step: 205
# pre_loc [259, 172, 144, 135]
# Tracking done in step: 206
# pre_loc [253, 171, 143, 133]
# Tracking done in step: 207
# pre_loc [254, 171, 136, 130]
# Tracking done in step: 208
# pre_loc [257, 173, 130, 129]
# Tracking done in step: 209
# pre_loc [259, 175, 117, 125]
# Tracking done in step: 210
# pre_loc [261, 179, 111, 130]
# Tracking done in step: 211
# pre_loc [267, 173, 117, 128]
# Tracking done in step: 212
# pre_loc [266, 175, 118, 125]
# Tracking done in step: 213
# pre_loc [264, 177, 114, 125]
# Tracking done in step: 214
# pre_loc [264, 179, 110, 122]
# Tracking done in step: 215
# pre_loc [262, 183, 97, 122]
# Tracking done in step: 216
# pre_loc [270, 180, 100, 120]
# Tracking done in step: 217
# pre_loc [267, 181, 103, 125]
# Tracking done in step: 218
# pre_loc [267, 176, 115, 128]
# Tracking done in step: 219
# pre_loc [267, 171, 122, 131]
# Tracking done in step: 220
# pre_loc [264, 173, 130, 135]
# Tracking done in step: 221
# pre_loc [261, 169, 138, 136]
# Tracking done in step: 222
# pre_loc [255, 172, 133, 129]
# Tracking done in step: 223
# pre_loc [258, 175, 125, 128]
# Tracking done in step: 224
# pre_loc [259, 175, 122, 128]
# Tracking done in step: 225
# pre_loc [262, 175, 124, 127]
# Tracking done in step: 226
# pre_loc [260, 177, 121, 126]
# Tracking done in step: 227
# pre_loc [262, 179, 120, 127]
# Tracking done in step: 228
# pre_loc [263, 177, 121, 124]
# Tracking done in step: 229
# pre_loc [263, 181, 121, 127]
# Tracking done in step: 230
# pre_loc [263, 176, 124, 126]
# Tracking done in step: 231
# pre_loc [262, 178, 121, 126]
# Tracking done in step: 232
# pre_loc [262, 178, 121, 123]
# Tracking done in step: 233
# pre_loc [262, 182, 118, 125]
# Tracking done in step: 234
# pre_loc [263, 179, 119, 125]
# Tracking done in step: 235
# pre_loc [265, 179, 121, 126]
# Tracking done in step: 236
# pre_loc [265, 178, 123, 130]
# Tracking done in step: 237
# pre_loc [263, 175, 124, 130]
# Tracking done in step: 238
# pre_loc [263, 172, 121, 127]
# Tracking done in step: 239
# pre_loc [263, 176, 115, 125]
# Tracking done in step: 240
# pre_loc [267, 178, 114, 128]
# Tracking done in step: 241
# pre_loc [267, 173, 115, 127]
# Tracking done in step: 242
# pre_loc [266, 175, 117, 126]
# Tracking done in step: 243
# pre_loc [264, 175, 117, 127]
# Tracking done in step: 244
# pre_loc [265, 175, 115, 125]
# Tracking done in step: 245
# pre_loc [265, 177, 114, 129]
# Tracking done in step: 246
# pre_loc [267, 174, 116, 126]
# Tracking done in step: 247
# pre_loc [266, 175, 116, 126]
# Tracking done in step: 248
# pre_loc [265, 175, 116, 128]
# Tracking done in step: 249
# pre_loc [265, 173, 118, 125]
# Tracking done in step: 250
# pre_loc [261, 177, 110, 121]
# Tracking done in step: 251
# pre_loc [267, 179, 109, 119]
# Tracking done in step: 252
# pre_loc [265, 183, 108, 122]
# Tracking done in step: 253
# pre_loc [265, 178, 111, 122]
# Tracking done in step: 254
# pre_loc [263, 183, 108, 119]
# Tracking done in step: 255
# pre_loc [266, 183, 105, 121]
# Tracking done in step: 256
# pre_loc [269, 180, 109, 126]
# Tracking done in step: 257
# pre_loc [268, 176, 113, 121]
# Tracking done in step: 258
# pre_loc [265, 180, 109, 121]
# Tracking done in step: 259
# pre_loc [265, 184, 102, 118]
# Tracking done in step: 260
# pre_loc [267, 181, 99, 123]
# Tracking done in step: 261
# pre_loc [271, 178, 112, 127]
# Tracking done in step: 262
# pre_loc [271, 174, 124, 128]
# Tracking done in step: 263
# pre_loc [262, 175, 120, 131]
# Tracking done in step: 264
# pre_loc [264, 172, 129, 129]
# Tracking done in step: 265
# pre_loc [261, 175, 127, 130]
# Tracking done in step: 266
# pre_loc [262, 171, 130, 128]
# Tracking done in step: 267
# pre_loc [260, 176, 130, 127]
# Tracking done in step: 268
# pre_loc [260, 174, 128, 127]
# Tracking done in step: 269
# pre_loc [262, 175, 125, 128]
# Tracking done in step: 270
# pre_loc [265, 175, 124, 131]
# Tracking done in step: 271
# pre_loc [266, 172, 130, 128]
# Tracking done in step: 272
# pre_loc [264, 177, 130, 128]
# Tracking done in step: 273
# pre_loc [264, 174, 130, 127]
# Tracking done in step: 274
# pre_loc [267, 177, 128, 125]
# Tracking done in step: 275
# pre_loc [268, 177, 125, 125]
# Tracking done in step: 276
# pre_loc [269, 180, 119, 126]
# Tracking done in step: 277
# pre_loc [276, 179, 121, 124]
# Tracking done in step: 278
# pre_loc [277, 179, 121, 128]
# Tracking done in step: 279
# pre_loc [278, 176, 125, 125]
# Tracking done in step: 280
# pre_loc [279, 182, 119, 130]
# Tracking done in step: 281
# pre_loc [282, 178, 120, 125]
# Tracking done in step: 282
# pre_loc [282, 181, 118, 132]
# Tracking done in step: 283
# pre_loc [285, 178, 131, 134]
# Tracking done in step: 284
# pre_loc [287, 178, 128, 132]
# Tracking done in step: 285
# pre_loc [289, 178, 131, 134]
# Tracking done in step: 286
# pre_loc [288, 175, 123, 125]
# Tracking done in step: 287
# pre_loc [289, 183, 119, 130]
# Tracking done in step: 288
# pre_loc [295, 182, 131, 137]
# Tracking done in step: 289
# pre_loc [292, 175, 132, 131]
# Tracking done in step: 290
# pre_loc [290, 182, 129, 129]
# Tracking done in step: 291
# pre_loc [295, 179, 126, 127]
# Tracking done in step: 292
# pre_loc [295, 185, 124, 128]
# Tracking done in step: 293
# pre_loc [302, 181, 135, 130]
# Tracking done in step: 294
# pre_loc [302, 183, 138, 133]
# Tracking done in step: 295
# pre_loc [302, 178, 125, 119]
# Tracking done in step: 296
# pre_loc [303, 193, 117, 119]
# Tracking done in step: 297
# pre_loc [306, 189, 117, 122]
# Tracking done in step: 298
# pre_loc [311, 188, 127, 128]
# Tracking done in step: 299
# pre_loc [311, 183, 141, 134]
# Tracking done in step: 300
# pre_loc [319, 225, 168, 220]
# Tracking done in step: 301
# pre_loc [310, 164, 198, 208]
# Tracking done in step: 302
# pre_loc [287, 170, 188, 199]
# Tracking done in step: 303
# pre_loc [289, 171, 177, 188]
# Tracking done in step: 304
# pre_loc [294, 173, 169, 176]
# Tracking done in step: 305
# pre_loc [297, 180, 172, 180]
# Tracking done in step: 306
# pre_loc [292, 183, 176, 190]
# Tracking done in step: 307
# pre_loc [293, 180, 184, 198]
# Tracking done in step: 308
# pre_loc [281, 174, 194, 200]
# Tracking done in step: 309
# pre_loc [277, 175, 203, 207]
# Tracking done in step: 310
# pre_loc [271, 177, 200, 221]
# Tracking done in step: 311
# pre_loc [273, 160, 207, 204]
# Tracking done in step: 312
# pre_loc [266, 164, 184, 188]
# Tracking done in step: 313
# pre_loc [276, 167, 188, 182]
# Tracking done in step: 314
# pre_loc [270, 179, 190, 197]
# Tracking done in step: 315
# pre_loc [270, 176, 206, 215]
# Tracking done in step: 316
# pre_loc [260, 161, 215, 210]
# Tracking done in step: 317
# pre_loc [252, 168, 215, 215]
# Tracking done in step: 318
# pre_loc [257, 159, 203, 203]
# Tracking done in step: 319
# pre_loc [260, 156, 192, 180]
# Tracking done in step: 320
# pre_loc [267, 180, 203, 212]
# Tracking done in step: 321
# pre_loc [257, 158, 203, 198]
# Tracking done in step: 322
# pre_loc [261, 161, 198, 187]
# Tracking done in step: 323
# pre_loc [266, 168, 191, 187]
# Tracking done in step: 324
# pre_loc [267, 165, 189, 174]
# Tracking done in step: 325
# pre_loc [269, 175, 198, 189]
# Tracking done in step: 326
# pre_loc [263, 171, 191, 196]
# Tracking done in step: 327
# pre_loc [269, 166, 205, 205]
# Tracking done in step: 328
# pre_loc [261, 167, 198, 203]
# Tracking done in step: 329
# pre_loc [261, 160, 194, 189]
# Tracking done in step: 330
# pre_loc [267, 165, 190, 183]
# Tracking done in step: 331
# pre_loc [268, 169, 188, 181]
# Tracking done in step: 332
# pre_loc [271, 177, 195, 193]
# Tracking done in step: 333
# pre_loc [265, 172, 193, 199]
# Tracking done in step: 334
# pre_loc [267, 165, 194, 194]
# Tracking done in step: 335
# pre_loc [265, 163, 183, 183]
# Tracking done in step: 336
# pre_loc [272, 177, 197, 203]
# Tracking done in step: 337
# pre_loc [267, 171, 194, 210]
# Tracking done in step: 338
# pre_loc [267, 167, 215, 222]
# Tracking done in step: 339
# pre_loc [253, 153, 215, 210]
# Tracking done in step: 340
# pre_loc [266, 168, 208, 212]
# Tracking done in step: 341
# pre_loc [256, 166, 212, 220]
# Tracking done in step: 342
# pre_loc [256, 158, 220, 220]
# Tracking done in step: 343
# pre_loc [247, 162, 223, 220]
# Tracking done in step: 344
# pre_loc [249, 155, 208, 206]
# Tracking done in step: 345
# pre_loc [259, 167, 206, 201]
# Tracking done in step: 346
# pre_loc [257, 170, 208, 208]
# Tracking done in step: 347
# pre_loc [252, 166, 213, 206]
# Tracking done in step: 348
# pre_loc [249, 166, 223, 209]
# Tracking done in step: 349
# pre_loc [239, 164, 218, 210]
# Tracking done in step: 350
# pre_loc [234, 153, 204, 177]
# Tracking done in step: 351
# pre_loc [247, 187, 214, 204]
# Tracking done in step: 352
# pre_loc [244, 172, 214, 195]
# Tracking done in step: 353
# pre_loc [217, 142, 171, 131]
# Tracking done in step: 354
# pre_loc [228, 174, 152, 129]
# Tracking done in step: 355
# pre_loc [224, 175, 135, 128]
# Tracking done in step: 356
# pre_loc [229, 172, 121, 127]
# Tracking done in step: 357
# pre_loc [236, 176, 110, 122]
# Tracking done in step: 358
# pre_loc [242, 180, 107, 120]
# Tracking done in step: 359
# pre_loc [244, 183, 103, 121]
# Tracking done in step: 360
# pre_loc [247, 179, 106, 122]
# Tracking done in step: 361
# pre_loc [246, 179, 112, 122]
# Tracking done in step: 362
# pre_loc [246, 179, 111, 123]
# Tracking done in step: 363
# pre_loc [246, 179, 112, 121]
# Tracking done in step: 364
# pre_loc [245, 182, 106, 119]
# Tracking done in step: 365
# pre_loc [248, 182, 107, 122]
# Tracking done in step: 366
# pre_loc [248, 179, 108, 122]
# Tracking done in step: 367
# pre_loc [248, 182, 105, 120]
# Tracking done in step: 368
# pre_loc [248, 182, 97, 117]
# Tracking done in step: 369
# pre_loc [253, 185, 101, 118]
# Tracking done in step: 370
# pre_loc [251, 181, 102, 119]
# Tracking done in step: 371
# pre_loc [249, 181, 108, 121]
# Tracking done in step: 372
# pre_loc [248, 181, 109, 121]
# Tracking done in step: 373
# pre_loc [248, 181, 110, 121]
# Tracking done in step: 374
# pre_loc [245, 179, 109, 121]
# Tracking done in step: 375
# pre_loc [248, 181, 117, 126]
# Tracking done in step: 376
# pre_loc [244, 176, 124, 126]
# Tracking done in step: 377
# pre_loc [239, 178, 126, 127]
# Tracking done in step: 378
# pre_loc [241, 175, 132, 132]
# Tracking done in step: 379
# pre_loc [239, 172, 135, 129]
# Tracking done in step: 380
# pre_loc [238, 175, 136, 127]
# Tracking done in step: 381
# pre_loc [234, 175, 138, 129]
# Tracking done in step: 382
# pre_loc [233, 175, 139, 129]
# Tracking done in step: 383
# pre_loc [233, 175, 143, 132]
# Tracking done in step: 384
# pre_loc [226, 175, 130, 127]
# Tracking done in step: 385
# pre_loc [228, 180, 114, 117]
# Tracking done in step: 386
# pre_loc [227, 185, 100, 121]
# Tracking done in step: 387
# pre_loc [234, 183, 103, 115]
# Tracking done in step: 388
# pre_loc [228, 190, 93, 109]
# Tracking done in step: 389
# pre_loc [228, 190, 87, 111]
# Tracking done in step: 390
# pre_loc [229, 188, 93, 117]
# Tracking done in step: 391
# pre_loc [227, 184, 101, 123]
# Tracking done in step: 392
# pre_loc [222, 180, 105, 129]
# Tracking done in step: 393
# pre_loc [219, 180, 109, 132]
# Tracking done in step: 394
# pre_loc [216, 177, 114, 132]
# Tracking done in step: 395
# pre_loc [211, 177, 114, 135]
# Tracking done in step: 396
# pre_loc [209, 177, 117, 133]
# Tracking done in step: 397
# pre_loc [211, 175, 114, 130]
# Tracking done in step: 398
# pre_loc [211, 178, 108, 134]
# Tracking done in step: 399
# pre_loc [215, 173, 110, 128]
# Tracking done in step: 400
# pre_loc [213, 180, 108, 134]
# Tracking done in step: 401
# pre_loc [215, 177, 111, 132]
# Tracking done in step: 402
# pre_loc [215, 177, 114, 129]
# Tracking done in step: 403
# pre_loc [212, 182, 112, 133]
# Tracking done in step: 404
# pre_loc [215, 179, 125, 140]
# Tracking done in step: 405
# pre_loc [213, 172, 137, 150]
# Tracking done in step: 406
# pre_loc [206, 167, 140, 141]
# Tracking done in step: 407
# pre_loc [208, 173, 127, 132]
# Tracking done in step: 408
# pre_loc [213, 178, 110, 126]
# Tracking done in step: 409
# pre_loc [219, 184, 102, 121]
# Tracking done in step: 410
# pre_loc [226, 182, 93, 118]
# Tracking done in step: 411
# pre_loc [237, 187, 90, 112]
# Tracking done in step: 412
# pre_loc [235, 190, 87, 110]
# Tracking done in step: 413
# pre_loc [243, 192, 88, 110]
# Tracking done in step: 414
# pre_loc [248, 197, 96, 108]
# Tracking done in step: 415
# pre_loc [252, 195, 97, 106]
# Tracking done in step: 416
# pre_loc [256, 196, 88, 107]
# Tracking done in step: 417
# pre_loc [261, 194, 87, 108]
# Tracking done in step: 418
# pre_loc [265, 192, 94, 109]
# Tracking done in step: 419
# pre_loc [265, 193, 98, 115]
# Tracking done in step: 420
# pre_loc [266, 185, 100, 120]
# Tracking done in step: 421
# pre_loc [266, 178, 111, 124]
# Tracking done in step: 422
# pre_loc [264, 178, 113, 127]
# Tracking done in step: 423
# pre_loc [266, 174, 124, 128]
# Tracking done in step: 424
# pre_loc [260, 175, 125, 140]
# Tracking done in step: 425
# pre_loc [260, 167, 132, 131]
# Tracking done in step: 426
# pre_loc [257, 175, 126, 131]
# Tracking done in step: 427
# pre_loc [259, 172, 126, 128]
# Tracking done in step: 428
# pre_loc [256, 173, 127, 131]
# Tracking done in step: 429
# pre_loc [260, 174, 125, 128]
# Tracking done in step: 430
# pre_loc [257, 174, 115, 125]
# Tracking done in step: 431
# pre_loc [260, 179, 110, 125]
# Tracking done in step: 432
# pre_loc [263, 178, 107, 123]
# Tracking done in step: 433
# pre_loc [263, 180, 105, 127]
# Tracking done in step: 434
# pre_loc [267, 177, 111, 121]
# Tracking done in step: 435
# pre_loc [264, 179, 107, 122]
# Tracking done in step: 436
# pre_loc [265, 182, 108, 126]
# Tracking done in step: 437
# pre_loc [260, 176, 114, 123]
# Tracking done in step: 438
# pre_loc [259, 178, 110, 128]
# Tracking done in step: 439
# pre_loc [265, 174, 124, 130]
# Tracking done in step: 440
# pre_loc [258, 170, 128, 134]
# Tracking done in step: 441
# pre_loc [258, 169, 131, 129]
# Tracking done in step: 442
# pre_loc [254, 174, 129, 128]
# Tracking done in step: 443
# pre_loc [254, 171, 122, 127]
# Tracking done in step: 444
# pre_loc [257, 173, 122, 129]
# Tracking done in step: 445
# pre_loc [258, 169, 120, 125]
# Tracking done in step: 446
# pre_loc [258, 173, 119, 122]
# Tracking done in step: 447
# pre_loc [258, 171, 116, 124]
# Tracking done in step: 448
# pre_loc [262, 168, 120, 125]
# Tracking done in step: 449
# pre_loc [256, 170, 122, 122]
# Tracking done in step: 450
# pre_loc [256, 171, 120, 122]
# Tracking done in step: 451
# pre_loc [256, 168, 123, 126]
# Tracking done in step: 452
# pre_loc [257, 168, 120, 120]
# Tracking done in step: 453
# pre_loc [257, 172, 119, 117]
# Tracking done in step: 454
# pre_loc [258, 174, 116, 116]
# Tracking done in step: 455
# pre_loc [257, 172, 110, 115]
# Tracking done in step: 456
# pre_loc [259, 175, 104, 112]
# Tracking done in step: 457
# pre_loc [259, 178, 98, 107]
# Tracking done in step: 458
# pre_loc [263, 181, 89, 99]
# Tracking done in step: 459
# pre_loc [265, 190, 86, 97]
# Tracking done in step: 460
# pre_loc [266, 190, 83, 91]
# Tracking done in step: 461
# pre_loc [266, 198, 86, 96]
# Tracking done in step: 462
# pre_loc [266, 192, 95, 105]
# Tracking done in step: 463
# pre_loc [266, 187, 105, 111]
# Tracking done in step: 464
# pre_loc [260, 183, 112, 118]
# Tracking done in step: 465
# pre_loc [257, 179, 112, 120]
# Tracking done in step: 466
# pre_loc [259, 175, 116, 116]
# Tracking done in step: 467
# pre_loc [256, 178, 108, 112]
# Tracking done in step: 468
# pre_loc [259, 180, 107, 115]
# Tracking done in step: 469
# pre_loc [262, 178, 109, 117]
# Tracking done in step: 470
# pre_loc [262, 179, 114, 123]
# Tracking done in step: 471
# pre_loc [257, 174, 117, 114]
# Tracking done in step: 472
# pre_loc [257, 177, 109, 106]
# Tracking done in step: 473
# pre_loc [259, 184, 102, 109]
# Tracking done in step: 474
# pre_loc [262, 180, 103, 116]
# Tracking done in step: 475
# pre_loc [264, 180, 111, 116]
# Tracking done in step: 476
# pre_loc [260, 178, 115, 112]
# Tracking done in step: 477
# pre_loc [258, 180, 112, 114]
# Tracking done in step: 478
# pre_loc [261, 180, 107, 121]
# Tracking done in step: 479
# pre_loc [263, 180, 119, 126]
# Tracking done in step: 480
# pre_loc [258, 174, 113, 117]
# Tracking done in step: 481
# pre_loc [264, 179, 112, 110]
# Tracking done in step: 482
# pre_loc [265, 182, 101, 106]
# Tracking done in step: 483
# pre_loc [274, 187, 99, 107]
# Tracking done in step: 484
# pre_loc [275, 188, 98, 103]
# Tracking done in step: 485
# pre_loc [275, 189, 90, 98]
# Tracking done in step: 486
# pre_loc [280, 193, 86, 100]
# Tracking done in step: 487
# pre_loc [286, 189, 89, 100]
# Tracking done in step: 488
# pre_loc [287, 195, 85, 103]
# Tracking done in step: 489
# pre_loc [291, 189, 93, 105]
# Tracking done in step: 490
# pre_loc [291, 190, 88, 107]
# Tracking done in step: 491
# pre_loc [293, 187, 91, 104]
# Tracking done in step: 492
# pre_loc [296, 188, 92, 105]
# Tracking done in step: 493
# pre_loc [296, 187, 97, 106]
# Tracking done in step: 494
# pre_loc [293, 189, 99, 110]
# Tracking done in step: 495
# pre_loc [291, 190, 100, 114]
# Tracking done in step: 496
# pre_loc [286, 186, 100, 112]
# Tracking done in step: 497
# pre_loc [286, 187, 98, 107]
# Tracking done in step: 498
# pre_loc [284, 191, 89, 103]
# Tracking done in step: 499
# pre_loc [287, 191, 86, 100]
# Tracking done in step: 500
# pre_loc [284, 193, 90, 100]
# Tracking done in step: 501
# pre_loc [278, 195, 88, 106]
# Tracking done in step: 502
# pre_loc [278, 191, 101, 106]
# Tracking done in step: 503
# pre_loc [269, 191, 95, 109]
# Tracking done in step: 504
# pre_loc [268, 189, 100, 106]
# Tracking done in step: 505
# pre_loc [262, 191, 95, 103]
# Tracking done in step: 506
# pre_loc [266, 193, 97, 107]
# Tracking done in step: 507
# pre_loc [261, 191, 96, 104]
# Tracking done in step: 508
# pre_loc [258, 191, 99, 106]
# Tracking done in step: 509
# pre_loc [252, 194, 101, 108]
# Tracking done in step: 510
# pre_loc [245, 197, 100, 109]
# Tracking done in step: 511
# pre_loc [241, 197, 106, 117]
# Tracking done in step: 512
# pre_loc [234, 191, 114, 123]
# Tracking done in step: 513
# pre_loc [227, 191, 122, 139]
# Tracking done in step: 514
# pre_loc [223, 191, 125, 160]
# Tracking done in step: 515
# pre_loc [222, 183, 137, 185]
# Tracking done in step: 516
# pre_loc [213, 160, 169, 181]
# Tracking done in step: 517
# pre_loc [198, 160, 149, 161]
# Tracking done in step: 518
# pre_loc [198, 158, 127, 139]
# Tracking done in step: 519
# pre_loc [212, 171, 125, 128]
# Tracking done in step: 520
# pre_loc [213, 174, 120, 121]
# Tracking done in step: 521
# pre_loc [215, 181, 113, 128]
# Tracking done in step: 522
# pre_loc [220, 175, 122, 137]
# Tracking done in step: 523
# pre_loc [215, 174, 122, 145]
# Tracking done in step: 524
# pre_loc [211, 168, 129, 143]
# Tracking done in step: 525
# pre_loc [218, 169, 131, 136]
# Tracking done in step: 526
# pre_loc [219, 178, 130, 136]
# Tracking done in step: 527
# pre_loc [223, 180, 124, 138]
# Tracking done in step: 528
# pre_loc [228, 173, 124, 132]
# Tracking done in step: 529
# pre_loc [228, 181, 123, 135]
# Tracking done in step: 530
# pre_loc [237, 181, 117, 132]
# Tracking done in step: 531
# pre_loc [239, 181, 119, 125]
# Tracking done in step: 532
# pre_loc [238, 182, 112, 111]
# Tracking done in step: 533
# pre_loc [251, 189, 100, 100]
# Tracking done in step: 534
# pre_loc [257, 200, 77, 89]
# Tracking done in step: 535
# pre_loc [270, 209, 67, 77]
# Tracking done in step: 536
# pre_loc [276, 221, 60, 63]
# Tracking done in step: 537
# pre_loc [283, 230, 50, 55]
# Tracking done in step: 538
# pre_loc [295, 230, 51, 62]
# Tracking done in step: 539
# pre_loc [295, 222, 58, 68]
# Tracking done in step: 540
# pre_loc [294, 219, 58, 74]
# Tracking done in step: 541
# pre_loc [296, 214, 69, 79]
# Tracking done in step: 542
# pre_loc [292, 217, 73, 77]
# Tracking done in step: 543
# pre_loc [295, 214, 64, 72]
# Tracking done in step: 544
# pre_loc [299, 214, 65, 77]
# Tracking done in step: 545
# pre_loc [305, 210, 60, 76]
# Tracking done in step: 546
# pre_loc [306, 210, 67, 75]
# Tracking done in step: 547
# pre_loc [305, 212, 64, 70]
# Tracking done in step: 548
# pre_loc [306, 216, 62, 66]
# Tracking done in step: 549
# pre_loc [307, 218, 62, 63]
# Tracking done in step: 550
# pre_loc [309, 220, 59, 64]
# Tracking done in step: 551
# pre_loc [312, 219, 57, 65]
# Tracking done in step: 552
# pre_loc [311, 217, 57, 68]
# Tracking done in step: 553
# pre_loc [311, 212, 60, 77]
# Tracking done in step: 554
# pre_loc [301, 208, 66, 81]
# Tracking done in step: 555
# pre_loc [296, 199, 73, 93]
# Tracking done in step: 556
# pre_loc [294, 195, 94, 108]
# Tracking done in step: 557
# pre_loc [283, 204, 112, 153]
# Tracking done in step: 558
# pre_loc [287, 158, 134, 117]
# Tracking done in step: 559
# pre_loc [266, 179, 120, 117]
# Tracking done in step: 560
# pre_loc [270, 180, 101, 107]
# Tracking done in step: 561
# pre_loc [284, 184, 87, 98]
# Tracking done in step: 562
# pre_loc [291, 189, 76, 94]
# Tracking done in step: 563
# pre_loc [300, 195, 68, 94]
# Tracking done in step: 564
# pre_loc [304, 190, 74, 91]
# Tracking done in step: 565
# pre_loc [300, 197, 74, 93]
# Tracking done in step: 566
# pre_loc [302, 194, 82, 99]
# Tracking done in step: 567
# pre_loc [299, 189, 88, 105]
# Tracking done in step: 568
# pre_loc [297, 187, 98, 106]
# Tracking done in step: 569
# pre_loc [295, 186, 96, 107]
# Tracking done in step: 570
# pre_loc [296, 185, 97, 105]
# Tracking done in step: 571
# pre_loc [298, 182, 97, 101]
# Tracking done in step: 572
# pre_loc [299, 185, 91, 100]
# Tracking done in step: 573
# pre_loc [301, 185, 90, 103]
# Tracking done in step: 574
# pre_loc [306, 183, 98, 105]
# Tracking done in step: 575
# pre_loc [303, 184, 102, 109]
# Tracking done in step: 576
# pre_loc [299, 185, 99, 109]
# Tracking done in step: 577
# pre_loc [302, 179, 103, 103]
# Tracking done in step: 578
# pre_loc [304, 185, 98, 106]
# Tracking done in step: 579
# pre_loc [305, 183, 97, 108]
# Tracking done in step: 580
# pre_loc [304, 183, 95, 107]
# Tracking done in step: 581
# pre_loc [307, 180, 95, 99]
# Tracking done in step: 582
# pre_loc [310, 186, 83, 96]
# Tracking done in step: 583
# pre_loc [312, 189, 78, 96]
# Tracking done in step: 584
# pre_loc [316, 189, 79, 97]
# Tracking done in step: 585
# pre_loc [319, 190, 85, 99]
# Tracking done in step: 586
# pre_loc [314, 187, 82, 99]
# Tracking done in step: 587
# pre_loc [315, 187, 88, 96]
# Tracking done in step: 588
# pre_loc [315, 193, 85, 111]
# Tracking done in step: 589
# pre_loc [319, 184, 109, 119]
# Tracking done in step: 590
# pre_loc [311, 176, 114, 113]
# Tracking done in step: 591
# pre_loc [305, 177, 102, 102]
# Tracking done in step: 592
# pre_loc [313, 184, 96, 103]
# Tracking done in step: 593
# pre_loc [314, 186, 94, 106]
# Tracking done in step: 594
# pre_loc [318, 182, 106, 108]
# Tracking done in step: 595
# pre_loc [312, 178, 97, 98]
# Tracking done in step: 596
# pre_loc [317, 186, 86, 96]
# Tracking done in step: 597
# pre_loc [322, 185, 81, 93]
# Tracking done in step: 598
# pre_loc [326, 188, 80, 96]
# Tracking done in step: 599
# pre_loc [326, 190, 84, 103]
# Tracking done in step: 600
# pre_loc [328, 182, 91, 99]
# Tracking done in step: 601
# pre_loc [324, 183, 86, 93]
# Tracking done in step: 602
# pre_loc [328, 188, 80, 91]
# Tracking done in step: 603
# pre_loc [331, 191, 77, 92]
# Tracking done in step: 604
# pre_loc [333, 188, 81, 91]
# Tracking done in step: 605
# pre_loc [331, 189, 83, 91]
# Tracking done in step: 606
# pre_loc [333, 187, 79, 90]
# Tracking done in step: 607
# pre_loc [337, 188, 77, 94]
# Tracking done in step: 608
# pre_loc [339, 186, 81, 90]
# Tracking done in step: 609
# pre_loc [340, 189, 80, 92]
# Tracking done in step: 610
# pre_loc [340, 187, 79, 87]
# Tracking done in step: 611
# pre_loc [346, 188, 78, 90]
# Tracking done in step: 612
# pre_loc [349, 187, 84, 93]
# Tracking done in step: 613
# pre_loc [344, 188, 81, 93]
# Tracking done in step: 614
# pre_loc [348, 188, 90, 93]
# Tracking done in step: 615
# pre_loc [347, 186, 83, 90]
# Tracking done in step: 616
# pre_loc [352, 186, 82, 93]
# Tracking done in step: 617
# pre_loc [355, 183, 87, 91]
# Tracking done in step: 618
# pre_loc [353, 189, 82, 93]
# Tracking done in step: 619
# pre_loc [357, 187, 91, 93]
# Tracking done in step: 620
# pre_loc [352, 187, 88, 93]
# Tracking done in step: 621
# pre_loc [358, 184, 95, 92]
# Tracking done in step: 622
# pre_loc [355, 187, 96, 92]
# Tracking done in step: 623
# pre_loc [356, 185, 99, 97]
# Tracking done in step: 624
# pre_loc [351, 181, 98, 86]
# Tracking done in step: 625
# pre_loc [351, 188, 94, 92]
# Tracking done in step: 626
# pre_loc [348, 187, 89, 95]
# Tracking done in step: 627
# pre_loc [350, 184, 91, 91]
# Tracking done in step: 628
# pre_loc [347, 187, 81, 89]
# Tracking done in step: 629
# pre_loc [349, 190, 82, 87]
# Tracking done in step: 630
# pre_loc [348, 187, 78, 89]
# Tracking done in step: 631
# pre_loc [347, 188, 85, 93]
# Tracking done in step: 632
# pre_loc [344, 186, 92, 91]
# Tracking done in step: 633
# pre_loc [335, 191, 83, 94]
# Tracking done in step: 634
# pre_loc [341, 187, 98, 94]
# Tracking done in step: 635
# pre_loc [330, 207, 90, 132]
# Tracking done in step: 636
# pre_loc [357, 224, 165, 223]
# Tracking done in step: 637
# pre_loc [302, 286, 134, 124]
# Tracking done in step: 638
# pre_loc [332, 306, 99, 117]
# Tracking done in step: 639
# pre_loc [354, 257, 172, 192]
# Tracking done in step: 640
# pre_loc [304, 158, 167, 132]
# Tracking done in step: 641
# pre_loc [311, 229, 152, 221]
# Tracking done in step: 642
# pre_loc [311, 222, 177, 209]
# Tracking done in step: 643
# pre_loc [326, 212, 109, 181]
# Tracking done in step: 644
# pre_loc [338, 246, 169, 209]
# Tracking done in step: 645
# pre_loc [335, 204, 107, 158]
# Tracking done in step: 646
# pre_loc [313, 161, 86, 102]
# Tracking done in step: 647
# pre_loc [350, 205, 145, 142]
# Tracking done in step: 648
# pre_loc [324, 178, 159, 134]
# Tracking done in step: 649
# pre_loc [330, 192, 178, 162]
# Tracking done in step: 650
# pre_loc [312, 175, 162, 140]
# Tracking done in step: 651
# pre_loc [321, 174, 160, 135]
# Tracking done in step: 652
# pre_loc [331, 180, 167, 137]
# Tracking done in step: 653
# pre_loc [330, 180, 176, 146]
# Tracking done in step: 654
# pre_loc [327, 180, 166, 139]
# Tracking done in step: 655
# pre_loc [342, 189, 168, 136]
# Tracking done in step: 656
# pre_loc [341, 190, 163, 135]
# Tracking done in step: 657
# pre_loc [339, 187, 152, 121]
# Tracking done in step: 658
# pre_loc [350, 239, 181, 223]
# Tracking done in step: 659
# pre_loc [282, 283, 173, 163]
# Tracking done in step: 660
# pre_loc [308, 311, 136, 119]
# Tracking done in step: 661
# pre_loc [374, 307, 121, 142]
# Tracking done in step: 662
# pre_loc [374, 286, 145, 142]
# Tracking done in step: 663
# pre_loc [369, 290, 137, 163]
# Tracking done in step: 664
# pre_loc [350, 315, 83, 97]
# Tracking done in step: 665
# pre_loc [333, 334, 63, 71]
# Tracking done in step: 666
# pre_loc [336, 334, 160, 161]
# Tracking done in step: 667
# pre_loc [350, 256, 143, 215]
# Tracking done in step: 668
# pre_loc [352, 155, 148, 86]
# Tracking done in step: 669
# pre_loc [355, 235, 204, 204]
# Tracking done in step: 670
# pre_loc [268, 295, 163, 79]
# Tracking done in step: 671
# pre_loc [312, 352, 154, 135]
# Tracking done in step: 672
# pre_loc [342, 283, 195, 212]
# Tracking done in step: 673
# pre_loc [287, 290, 198, 151]
# Tracking done in step: 674
# pre_loc [300, 316, 105, 97]
# Tracking done in step: 675
# pre_loc [348, 305, 120, 53]
# Tracking done in step: 676
# pre_loc [389, 327, 115, 133]
# Tracking done in step: 677
# pre_loc [383, 269, 174, 214]
# Tracking done in step: 678
# pre_loc [303, 295, 202, 109]
# Tracking done in step: 679
# pre_loc [285, 337, 202, 130]
# Tracking done in step: 680
# pre_loc [304, 333, 92, 83]
# Tracking done in step: 681
# pre_loc [320, 329, 194, 220]
# Tracking done in step: 682
# pre_loc [276, 288, 188, 135]
# Tracking done in step: 683
# pre_loc [293, 322, 182, 132]
# Tracking done in step: 684
# pre_loc [297, 330, 182, 133]
# Tracking done in step: 685
# pre_loc [299, 317, 178, 145]
# Tracking done in step: 686
# pre_loc [301, 310, 176, 152]
# Tracking done in step: 687
# pre_loc [316, 310, 129, 121]
# Tracking done in step: 688
# pre_loc [362, 258, 150, 217]
# Tracking done in step: 689
# pre_loc [302, 291, 215, 120]
# Tracking done in step: 690
# pre_loc [268, 337, 186, 155]
# Tracking done in step: 691
# pre_loc [299, 309, 178, 118]
# Tracking done in step: 692
# pre_loc [305, 323, 164, 128]
# Tracking done in step: 693
# pre_loc [316, 320, 137, 126]
# Tracking done in step: 694
# pre_loc [369, 303, 85, 106]
# Tracking done in step: 695
# pre_loc [415, 295, 74, 77]
# Tracking done in step: 696
# pre_loc [418, 306, 58, 49]
# Tracking done in step: 697
# pre_loc [423, 330, 51, 63]
# Tracking done in step: 698
# pre_loc [425, 326, 144, 148]
# Tracking done in step: 699
# pre_loc [355, 254, 161, 222]
# Tracking done in step: 700
# pre_loc [261, 298, 163, 93]
# Tracking done in step: 701
# pre_loc [328, 332, 123, 119]
# Tracking done in step: 702
# pre_loc [366, 285, 193, 210]
# Tracking done in step: 703
# pre_loc [296, 272, 128, 138]
# Tracking done in step: 704
# pre_loc [339, 301, 116, 118]
# Tracking done in step: 705
# pre_loc [397, 299, 85, 87]
# Tracking done in step: 706
# pre_loc [412, 307, 47, 60]
# Tracking done in step: 707
# pre_loc [426, 323, 37, 45]
# Tracking done in step: 708
# pre_loc [438, 331, 31, 31]
# Tracking done in step: 709
# pre_loc [439, 345, 20, 33]
# Tracking done in step: 710
# pre_loc [448, 343, 38, 42]
# Tracking done in step: 711
# pre_loc [445, 334, 47, 43]
# Tracking done in step: 712
# pre_loc [444, 335, 102, 105]
# Tracking done in step: 713
# pre_loc [424, 318, 182, 218]
# Tracking done in step: 714
# pre_loc [300, 237, 165, 213]
# Tracking done in step: 715
# pre_loc [290, 270, 161, 137]
# Tracking done in step: 716
# pre_loc [317, 322, 199, 138]
# Tracking done in step: 717
# pre_loc [295, 308, 135, 128]
# Tracking done in step: 718
# pre_loc [325, 322, 147, 142]
# Tracking done in step: 719
# pre_loc [313, 344, 189, 186]
# Tracking done in step: 720
# pre_loc [304, 312, 210, 139]
# Tracking done in step: 721
# pre_loc [266, 314, 163, 121]
# Tracking done in step: 722
# pre_loc [287, 314, 181, 114]
# Tracking done in step: 723
# pre_loc [254, 365, 161, 211]
# Tracking done in step: 724
# pre_loc [373, 242, 128, 213]
# Tracking done in step: 725
# pre_loc [395, 214, 130, 220]
# Tracking done in step: 726
# pre_loc [403, 212, 100, 203]
# Tracking done in step: 727
# pre_loc [419, 227, 101, 189]
# Tracking done in step: 728
# pre_loc [406, 235, 122, 193]
# Tracking done in step: 729
# pre_loc [395, 226, 111, 215]
# Tracking done in step: 730
# pre_loc [389, 211, 145, 220]
# Tracking done in step: 731
# pre_loc [379, 211, 127, 211]
# Tracking done in step: 732
# pre_loc [379, 216, 150, 218]
# Tracking done in step: 733
# pre_loc [376, 208, 140, 208]
# Tracking done in step: 734
# pre_loc [400, 217, 99, 208]
# Tracking done in step: 735
# pre_loc [422, 215, 99, 215]
# Tracking done in step: 736
# pre_loc [411, 211, 117, 222]
# Tracking done in step: 737
# pre_loc [387, 199, 111, 210]
# Tracking done in step: 738
# pre_loc [410, 213, 88, 205]
# Tracking done in step: 739
# pre_loc [427, 205, 112, 217]
# Tracking done in step: 740
# pre_loc [383, 201, 125, 205]
# Tracking done in step: 741
# pre_loc [405, 217, 96, 201]
# Tracking done in step: 742
# pre_loc [421, 210, 114, 215]
# Tracking done in step: 743
# pre_loc [398, 201, 98, 208]
# Tracking done in step: 744
# pre_loc [415, 209, 99, 220]
# Tracking done in step: 745
# pre_loc [400, 191, 108, 220]
# Tracking done in step: 746
# pre_loc [403, 195, 130, 216]
# Tracking done in step: 747
# pre_loc [366, 193, 139, 209]
# Tracking done in step: 748
# pre_loc [326, 167, 205, 149]
# Tracking done in step: 749
# pre_loc [321, 204, 201, 185]
# Tracking done in step: 750
# pre_loc [219, 183, 91, 58]
# Tracking done in step: 751
# pre_loc [285, 216, 90, 136]
# Tracking done in step: 752
# pre_loc [333, 181, 179, 129]
# Tracking done in step: 753
# pre_loc [308, 196, 217, 115]
# Tracking done in step: 754
# pre_loc [214, 286, 133, 171]
# Tracking done in step: 755
# pre_loc [339, 353, 129, 211]
# Tracking done in step: 756
# pre_loc [409, 229, 140, 220]
# Tracking done in step: 757
# pre_loc [385, 198, 159, 203]
# Tracking done in step: 758
# pre_loc [385, 195, 108, 180]
# Tracking done in step: 759
# pre_loc [302, 170, 132, 120]
# Tracking done in step: 760
# pre_loc [313, 198, 178, 160]
# Tracking done in step: 761
# pre_loc [299, 183, 190, 116]
# Tracking done in step: 762
# pre_loc [230, 221, 103, 88]
# Tracking done in step: 763
# pre_loc [322, 193, 69, 93]
# Tracking done in step: 764
# pre_loc [358, 189, 93, 100]
# Tracking done in step: 765
# pre_loc [349, 183, 94, 97]
# Tracking done in step: 766
# pre_loc [344, 187, 93, 99]
# Tracking done in step: 767
# pre_loc [347, 184, 87, 95]
# Tracking done in step: 768
# pre_loc [349, 183, 89, 89]
# Tracking done in step: 769
# pre_loc [348, 187, 83, 91]
# Tracking done in step: 770
# pre_loc [352, 185, 82, 89]
# Tracking done in step: 771
# pre_loc [348, 187, 83, 90]
# Tracking done in step: 772
# pre_loc [350, 185, 83, 89]
# Tracking done in step: 773
# pre_loc [348, 186, 82, 89]
# Tracking done in step: 774
# pre_loc [349, 186, 80, 84]
# Tracking done in step: 775
# pre_loc [349, 190, 73, 78]
# Tracking done in step: 776
# pre_loc [351, 195, 67, 77]
# Tracking done in step: 777
# pre_loc [352, 194, 65, 75]
# Tracking done in step: 778
# pre_loc [354, 197, 63, 75]
# Tracking done in step: 779
# pre_loc [356, 197, 62, 71]
# Tracking done in step: 780
# pre_loc [357, 201, 62, 69]
# Tracking done in step: 781
# pre_loc [358, 202, 59, 69]
# Tracking done in step: 782
# pre_loc [359, 203, 60, 67]
# Tracking done in step: 783
# pre_loc [359, 202, 60, 63]
# Tracking done in step: 784
# pre_loc [361, 206, 58, 68]
# Tracking done in step: 785
# pre_loc [359, 202, 60, 69]
# Tracking done in step: 786
# pre_loc [359, 202, 61, 68]
# Tracking done in step: 787
# pre_loc [358, 200, 63, 67]
# Tracking done in step: 788
# pre_loc [357, 201, 65, 71]
# Tracking done in step: 789
# pre_loc [357, 201, 66, 80]
# Tracking done in step: 790
# pre_loc [356, 191, 76, 82]
# Tracking done in step: 791
# pre_loc [350, 190, 79, 87]
# Tracking done in step: 792
# pre_loc [352, 188, 76, 85]
# Tracking done in step: 793
# pre_loc [351, 189, 72, 84]
# Tracking done in step: 794
# pre_loc [354, 189, 73, 79]
# Tracking done in step: 795
# pre_loc [353, 192, 70, 77]
# Tracking done in step: 796
# pre_loc [353, 199, 66, 78]
# Tracking done in step: 797
# pre_loc [356, 191, 70, 77]
# Tracking done in step: 798
# pre_loc [351, 193, 68, 79]
# Tracking done in step: 799
# pre_loc [354, 192, 70, 81]
# Tracking done in step: 800
# pre_loc [354, 192, 73, 83]
# Tracking done in step: 801
# pre_loc [354, 190, 75, 83]
# Tracking done in step: 802
# pre_loc [352, 190, 71, 81]
# Tracking done in step: 803
# pre_loc [353, 192, 72, 86]
# Tracking done in step: 804
# pre_loc [355, 188, 77, 89]
# Tracking done in step: 805
# pre_loc [354, 186, 82, 86]
# Tracking done in step: 806
# pre_loc [352, 190, 82, 88]
# Tracking done in step: 807
# pre_loc [352, 189, 82, 91]
# Tracking done in step: 808
# pre_loc [349, 187, 83, 90]
# Tracking done in step: 809
# pre_loc [349, 192, 73, 91]
# Tracking done in step: 810
# pre_loc [354, 190, 72, 88]
# Tracking done in step: 811
# pre_loc [354, 191, 73, 87]
# Tracking done in step: 812
# pre_loc [354, 192, 73, 89]
# Tracking done in step: 813
# pre_loc [353, 193, 75, 88]
# Tracking done in step: 814
# pre_loc [353, 192, 72, 84]
# Tracking done in step: 815
# pre_loc [352, 199, 68, 80]
# Tracking done in step: 816
# pre_loc [352, 199, 66, 74]
# Tracking done in step: 817
# pre_loc [356, 202, 57, 82]
# Tracking done in step: 818
# pre_loc [359, 198, 64, 83]
# Tracking done in step: 819
# pre_loc [357, 195, 68, 86]
# Tracking done in step: 820
# pre_loc [356, 195, 76, 92]
# Tracking done in step: 821
# pre_loc [352, 189, 86, 101]
# Tracking done in step: 822
# pre_loc [357, 183, 108, 99]
# Tracking done in step: 823
# pre_loc [343, 184, 118, 100]
# Tracking done in step: 824
# pre_loc [341, 184, 119, 99]
# Tracking done in step: 825
# pre_loc [341, 183, 121, 99]
# Tracking done in step: 826
# pre_loc [339, 184, 124, 99]
# Tracking done in step: 827
# pre_loc [339, 184, 125, 101]
# Tracking done in step: 828
# pre_loc [339, 183, 119, 96]
# Tracking done in step: 829
# pre_loc [340, 184, 117, 97]
# Tracking done in step: 830
# pre_loc [342, 182, 114, 96]
# Tracking done in step: 831
# pre_loc [343, 183, 111, 97]
# Tracking done in step: 832
# pre_loc [344, 184, 108, 96]
# Tracking done in step: 833
# pre_loc [344, 185, 110, 96]
# Tracking done in step: 834
# pre_loc [343, 184, 111, 96]
# Tracking done in step: 835
# pre_loc [344, 184, 110, 96]
# Tracking done in step: 836
# pre_loc [341, 185, 105, 96]
# Tracking done in step: 837
# pre_loc [341, 185, 94, 93]
# Tracking done in step: 838
# pre_loc [342, 190, 84, 91]
# Tracking done in step: 839
# pre_loc [347, 192, 82, 92]
# Tracking done in step: 840
# pre_loc [351, 187, 84, 94]
# Tracking done in step: 841
# pre_loc [347, 189, 83, 94]
# Tracking done in step: 842
# pre_loc [348, 192, 83, 100]
# Tracking done in step: 843
# pre_loc [349, 184, 91, 93]
# Tracking done in step: 844
# pre_loc [344, 191, 78, 93]
# Tracking done in step: 845
# pre_loc [351, 188, 82, 95]
# Tracking done in step: 846
# pre_loc [349, 189, 83, 93]
# Tracking done in step: 847
# pre_loc [348, 187, 77, 91]
# Tracking done in step: 848
# ...
# pre_loc [260, 208, 68, 95]
# Tracking done in step: 11717
# pre_loc [258, 202, 91, 102]
# Tracking done in step: 11718
# pre_loc [246, 197, 107, 111]
# Tracking done in step: 11719
# pre_loc [239, 192, 123, 115]
# Tracking done in step: 11720
# pre_loc [234, 194, 135, 132]
# Tracking done in step: 11721
# pre_loc [227, 185, 142, 136]
# Tracking done in step: 11722
# pre_loc [224, 183, 140, 129]
# Tracking done in step: 11723
# pre_loc [222, 185, 143, 123]
# Tracking done in step: 11724
# pre_loc [222, 188, 146, 125]
# Tracking done in step: 11725
# pre_loc [219, 227, 151, 212]
# Tracking done in step: 11726
# pre_loc [208, 176, 153, 167]
# Tracking done in step: 11727
# pre_loc [216, 169, 135, 128]
# Tracking done in step: 11728
# pre_loc [227, 185, 121, 114]
# Tracking done in step: 11729
# pre_loc [237, 188, 109, 106]
# Tracking done in step: 11730
# pre_loc [239, 192, 104, 102]
# Tracking done in step: 11731
# pre_loc [236, 196, 89, 105]
# Tracking done in step: 11732
# pre_loc [248, 196, 99, 105]
# Tracking done in step: 11733
# pre_loc [240, 196, 93, 102]
# Tracking done in step: 11734
# pre_loc [240, 196, 89, 102]
# Tracking done in step: 11735
# pre_loc [242, 197, 89, 102]
# Tracking done in step: 11736
# pre_loc [245, 195, 90, 99]
# Tracking done in step: 11737
# pre_loc [246, 196, 92, 101]
# Tracking done in step: 11738
# pre_loc [244, 196, 92, 102]
# Tracking done in step: 11739
# pre_loc [244, 198, 90, 105]
# Tracking done in step: 11740
# pre_loc [246, 195, 97, 102]
# Tracking done in step: 11741
# pre_loc [244, 195, 100, 105]
# Tracking done in step: 11742
# pre_loc [242, 196, 111, 112]
# Tracking done in step: 11743
# pre_loc [239, 191, 122, 117]
# Tracking done in step: 11744
# pre_loc [232, 192, 134, 127]
# Tracking done in step: 11745
# pre_loc [228, 188, 138, 129]
# Tracking done in step: 11746
# pre_loc [224, 191, 132, 136]
# Tracking done in step: 11747
# pre_loc [226, 181, 138, 119]
# Tracking done in step: 11748
# pre_loc [226, 193, 142, 135]
# Tracking done in step: 11749
# pre_loc [223, 185, 153, 142]
# Tracking done in step: 11750
# pre_loc [218, 208, 141, 185]
# Tracking done in step: 11751
# pre_loc [224, 166, 136, 127]
# Tracking done in step: 11752
# pre_loc [227, 187, 106, 100]
# Tracking done in step: 11753
# pre_loc [234, 202, 77, 95]
# Tracking done in step: 11754
# pre_loc [247, 204, 67, 84]
# Tracking done in step: 11755
# pre_loc [254, 217, 58, 75]
# Tracking done in step: 11756
# pre_loc [261, 220, 52, 55]
# Tracking done in step: 11757
# pre_loc [266, 234, 43, 43]
# Tracking done in step: 11758
# pre_loc [281, 240, 30, 39]
# Tracking done in step: 11759
# pre_loc [287, 243, 25, 33]
# Tracking done in step: 11760
# pre_loc [292, 248, 22, 32]
# Tracking done in step: 11761
# pre_loc [293, 247, 64, 69]
# Tracking done in step: 11762
# pre_loc [270, 232, 99, 119]
# Tracking done in step: 11763
# pre_loc [242, 191, 146, 138]
# Tracking done in step: 11764
# pre_loc [215, 221, 173, 221]
# Tracking done in step: 11765
# pre_loc [205, 158, 172, 145]
# Tracking done in step: 11766
# pre_loc [197, 226, 165, 220]
# Tracking done in step: 11767
# pre_loc [205, 147, 159, 122]
# Tracking done in step: 11768
# pre_loc [219, 214, 201, 208]
# Tracking done in step: 11769
# pre_loc [193, 152, 162, 160]
# Tracking done in step: 11770
# pre_loc [214, 209, 169, 220]
# Tracking done in step: 11771
# pre_loc [205, 156, 174, 159]
# Tracking done in step: 11772
# pre_loc [205, 167, 137, 120]
# Tracking done in step: 11773
# pre_loc [228, 189, 123, 117]
# Tracking done in step: 11774
# pre_loc [236, 188, 109, 107]
# Tracking done in step: 11775
# pre_loc [236, 195, 100, 102]
# Tracking done in step: 11776
# pre_loc [238, 196, 90, 102]
# Tracking done in step: 11777
# pre_loc [241, 197, 89, 102]
# Tracking done in step: 11778
# pre_loc [244, 197, 91, 99]
# Tracking done in step: 11779
# pre_loc [242, 202, 82, 105]
# Tracking done in step: 11780
# pre_loc [251, 196, 107, 109]
# Tracking done in step: 11781
# pre_loc [242, 193, 109, 111]
# Tracking done in step: 11782
# pre_loc [241, 190, 112, 110]
# Tracking done in step: 11783
# pre_loc [238, 190, 117, 112]
# Tracking done in step: 11784
# pre_loc [236, 189, 131, 116]
# Tracking done in step: 11785
# pre_loc [229, 188, 144, 129]
# Tracking done in step: 11786
# pre_loc [223, 228, 146, 218]
# Tracking done in step: 11787
# pre_loc [214, 189, 172, 223]
# Tracking done in step: 11788
# pre_loc [153, 290, 76, 79]
# Tracking done in step: 11789
# pre_loc [186, 290, 126, 194]
# Tracking done in step: 11790
# pre_loc [241, 158, 205, 177]
# Tracking done in step: 11791
# pre_loc [194, 174, 157, 150]
# Tracking done in step: 11792
# pre_loc [219, 178, 152, 138]
# Tracking done in step: 11793
# pre_loc [220, 181, 132, 125]
# Tracking done in step: 11794
# pre_loc [228, 185, 126, 114]
# Tracking done in step: 11795
# pre_loc [237, 189, 128, 112]
# Tracking done in step: 11796
# pre_loc [234, 191, 125, 117]
# Tracking done in step: 11797
# pre_loc [232, 189, 122, 119]
# Tracking done in step: 11798
# pre_loc [239, 187, 123, 116]
# Tracking done in step: 11799
# pre_loc [237, 187, 122, 113]
# Tracking done in step: 11800
# pre_loc [239, 189, 127, 114]
# Tracking done in step: 11801
# pre_loc [233, 191, 132, 119]
# Tracking done in step: 11802
# pre_loc [230, 188, 142, 128]
# Tracking done in step: 11803
# pre_loc [224, 189, 137, 135]
# Tracking done in step: 11804
# pre_loc [227, 185, 149, 129]
# Tracking done in step: 11805
# pre_loc [221, 187, 144, 131]
# Tracking done in step: 11806
# pre_loc [224, 184, 138, 126]
# Tracking done in step: 11807
# pre_loc [224, 187, 142, 122]
# Tracking done in step: 11808
# pre_loc [222, 189, 145, 124]
# Tracking done in step: 11809
# pre_loc [222, 189, 138, 129]
# Tracking done in step: 11810
# pre_loc [225, 185, 142, 118]
# Tracking done in step: 11811
# pre_loc [224, 187, 140, 121]
# Tracking done in step: 11812
# pre_loc [221, 192, 135, 126]
# Tracking done in step: 11813
# pre_loc [226, 188, 136, 124]
# Tracking done in step: 11814
# pre_loc [227, 191, 139, 133]
# Tracking done in step: 11815
# pre_loc [228, 187, 148, 140]
# Tracking done in step: 11816
# pre_loc [219, 215, 158, 216]
# Tracking done in step: 11817
# pre_loc [211, 163, 163, 156]
# Tracking done in step: 11818
# pre_loc [215, 172, 139, 137]
# Tracking done in step: 11819
# pre_loc [225, 180, 131, 125]
# Tracking done in step: 11820
# pre_loc [232, 185, 128, 112]
# Tracking done in step: 11821
# pre_loc [234, 192, 125, 117]
# Tracking done in step: 11822
# pre_loc [233, 191, 121, 118]
# Tracking done in step: 11823
# pre_loc [235, 188, 121, 118]
# Tracking done in step: 11824
# pre_loc [238, 188, 122, 117]
# Tracking done in step: 11825
# pre_loc [236, 187, 122, 112]
# Tracking done in step: 11826
# pre_loc [237, 189, 127, 114]
# Tracking done in step: 11827
# pre_loc [232, 192, 138, 122]
# Tracking done in step: 11828
# pre_loc [228, 188, 139, 135]
# Tracking done in step: 11829
# pre_loc [228, 184, 145, 134]
# Tracking done in step: 11830
# pre_loc [223, 217, 147, 203]
# Tracking done in step: 11831
# pre_loc [226, 156, 169, 167]
# Tracking done in step: 11832
# pre_loc [209, 167, 139, 131]
# Tracking done in step: 11833
# pre_loc [227, 183, 126, 114]
# Tracking done in step: 11834
# pre_loc [233, 191, 113, 106]
# Tracking done in step: 11835
# pre_loc [235, 194, 103, 104]
# Tracking done in step: 11836
# pre_loc [237, 192, 88, 99]
# Tracking done in step: 11837
# pre_loc [239, 202, 82, 107]
# Tracking done in step: 11838
# pre_loc [248, 194, 95, 102]
# Tracking done in step: 11839
# pre_loc [245, 196, 83, 102]
# Tracking done in step: 11840
# pre_loc [247, 195, 89, 103]
# Tracking done in step: 11841
# pre_loc [244, 197, 84, 105]
# Tracking done in step: 11842
# pre_loc [249, 193, 93, 100]
# Tracking done in step: 11843
# pre_loc [242, 200, 88, 113]
# Tracking done in step: 11844
# pre_loc [248, 191, 125, 120]
# Tracking done in step: 11845
# pre_loc [233, 188, 140, 128]
# Tracking done in step: 11846
# pre_loc [225, 186, 151, 140]
# Tracking done in step: 11847
# pre_loc [219, 198, 162, 179]
# Tracking done in step: 11848
# pre_loc [217, 167, 159, 153]
# Tracking done in step: 11849
# pre_loc [217, 171, 141, 132]
# Tracking done in step: 11850
# pre_loc [224, 179, 139, 121]
# Tracking done in step: 11851
# pre_loc [224, 189, 135, 117]
# Tracking done in step: 11852
# pre_loc [229, 189, 142, 120]
# Tracking done in step: 11853
# pre_loc [225, 189, 135, 128]
# Tracking done in step: 11854
# pre_loc [228, 186, 138, 118]
# Tracking done in step: 11855
# pre_loc [228, 188, 144, 124]
# Tracking done in step: 11856
# pre_loc [223, 190, 130, 126]
# Tracking done in step: 11857
# pre_loc [230, 184, 127, 114]
# Tracking done in step: 11858
# pre_loc [234, 190, 124, 108]
# Tracking done in step: 11859
# pre_loc [236, 194, 114, 109]
# Tracking done in step: 11860
# pre_loc [239, 192, 101, 102]
# Tracking done in step: 11861
# pre_loc [240, 195, 85, 104]
# Tracking done in step: 11862
# pre_loc [245, 195, 92, 102]
# Tracking done in step: 11863
# pre_loc [241, 199, 85, 108]
# Tracking done in step: 11864
# pre_loc [250, 192, 112, 112]
# Tracking done in step: 11865
# pre_loc [240, 188, 115, 113]
# Tracking done in step: 11866
# pre_loc [238, 191, 131, 121]
# Tracking done in step: 11867
# pre_loc [229, 189, 149, 139]
# Tracking done in step: 11868
# pre_loc [220, 184, 156, 147]
# Tracking done in step: 11869
# pre_loc [218, 175, 142, 125]
# Tracking done in step: 11870
# pre_loc [222, 186, 139, 120]
# Tracking done in step: 11871
# pre_loc [225, 189, 143, 118]
# Tracking done in step: 11872
# pre_loc [221, 193, 139, 130]
# Tracking done in step: 11873
# pre_loc [225, 186, 142, 123]
# Tracking done in step: 11874
# pre_loc [221, 188, 145, 124]
# Tracking done in step: 11875
# pre_loc [221, 187, 148, 130]
# Tracking done in step: 11876
# pre_loc [220, 187, 147, 137]
# Tracking done in step: 11877
# pre_loc [220, 180, 147, 124]
# Tracking done in step: 11878
# pre_loc [220, 189, 148, 133]
# Tracking done in step: 11879
# pre_loc [219, 186, 153, 140]
# Tracking done in step: 11880
# pre_loc [216, 184, 158, 146]
# Tracking done in step: 11881
# pre_loc [215, 178, 167, 151]
# Tracking done in step: 11882
# pre_loc [211, 175, 148, 135]
# Tracking done in step: 11883
# pre_loc [221, 180, 143, 123]
# Tracking done in step: 11884
# pre_loc [222, 186, 143, 120]
# Tracking done in step: 11885
# pre_loc [222, 189, 144, 122]
# Tracking done in step: 11886
# pre_loc [220, 190, 144, 131]
# Tracking done in step: 11887
# pre_loc [223, 184, 157, 130]
# Tracking done in step: 11888
# pre_loc [217, 185, 150, 133]
# Tracking done in step: 11889
# pre_loc [218, 184, 136, 128]
# Tracking done in step: 11890
# pre_loc [225, 182, 139, 118]
# Tracking done in step: 11891
# pre_loc [225, 187, 145, 122]
# Tracking done in step: 11892
# pre_loc [222, 191, 130, 124]
# Tracking done in step: 11893
# pre_loc [229, 185, 130, 112]
# Tracking done in step: 11894
# pre_loc [235, 196, 134, 127]
# Tracking done in step: 11895
# pre_loc [226, 186, 141, 129]
# Tracking done in step: 11896
# pre_loc [224, 203, 147, 166]
# Tracking done in step: 11897
# pre_loc [224, 190, 170, 194]
# Tracking done in step: 11898
# pre_loc [213, 159, 151, 133]
# Tracking done in step: 11899
# pre_loc [221, 207, 164, 188]
# Tracking done in step: 11900
# pre_loc [212, 158, 146, 134]
# Tracking done in step: 11901
# pre_loc [227, 208, 183, 198]
# Tracking done in step: 11902
# pre_loc [195, 167, 125, 121]
# Tracking done in step: 11903
# pre_loc [234, 194, 150, 146]
# Tracking done in step: 11904
# pre_loc [218, 182, 153, 146]
# Tracking done in step: 11905
# pre_loc [214, 177, 146, 131]
# Tracking done in step: 11906
# pre_loc [222, 190, 131, 131]
# Tracking done in step: 11907
# pre_loc [228, 182, 117, 104]
# Tracking done in step: 11908
# pre_loc [231, 196, 101, 104]
# Tracking done in step: 11909
# pre_loc [237, 197, 90, 104]
# Tracking done in step: 11910
# pre_loc [245, 194, 97, 104]
# Tracking done in step: 11911
# pre_loc [244, 196, 100, 112]
# Tracking done in step: 11912
# pre_loc [246, 190, 110, 111]
# Tracking done in step: 11913
# pre_loc [238, 191, 105, 103]
# Tracking done in step: 11914
# pre_loc [239, 195, 101, 112]
# Tracking done in step: 11915
# pre_loc [244, 190, 117, 117]
# Tracking done in step: 11916
# pre_loc [240, 188, 125, 113]
# Tracking done in step: 11917
# pre_loc [233, 192, 133, 118]
# Tracking done in step: 11918
# pre_loc [231, 189, 139, 128]
# Tracking done in step: 11919
# pre_loc [225, 192, 143, 146]
# Tracking done in step: 11920
# pre_loc [223, 179, 156, 139]
# Tracking done in step: 11921
# pre_loc [216, 219, 163, 222]
# Tracking done in step: 11922
# pre_loc [227, 136, 106, 81]
# Tracking done in step: 11923
# pre_loc [247, 200, 135, 109]
# Tracking done in step: 11924
# pre_loc [229, 203, 156, 144]
# Tracking done in step: 11925
# pre_loc [216, 187, 163, 170]
# Tracking done in step: 11926
# pre_loc [214, 183, 177, 196]
# Tracking done in step: 11927
# pre_loc [206, 155, 146, 133]
# Tracking done in step: 11928
# pre_loc [221, 202, 173, 186]
# Tracking done in step: 11929
# pre_loc [211, 158, 159, 128]
# Tracking done in step: 11930
# pre_loc [214, 211, 187, 210]
# Tracking done in step: 11931
# pre_loc [202, 150, 159, 135]
# Tracking done in step: 11932
# pre_loc [214, 202, 162, 189]
# Tracking done in step: 11933
# pre_loc [217, 154, 149, 132]
# Tracking done in step: 11934
# pre_loc [221, 186, 131, 127]
# Tracking done in step: 11935
# pre_loc [229, 185, 125, 117]
# Tracking done in step: 11936
# pre_loc [238, 188, 118, 110]
# Tracking done in step: 11937
# pre_loc [234, 193, 101, 103]
# Tracking done in step: 11938
# pre_loc [235, 204, 91, 118]
# Tracking done in step: 11939
# pre_loc [243, 197, 127, 131]
# Tracking done in step: 11940
# pre_loc [227, 197, 138, 149]
# Tracking done in step: 11941
# pre_loc [230, 178, 162, 139]
# Tracking done in step: 11942
# pre_loc [217, 187, 158, 138]
# Tracking done in step: 11943
# pre_loc [221, 186, 160, 142]
# Tracking done in step: 11944
# pre_loc [213, 183, 139, 137]
# Tracking done in step: 11945
# pre_loc [221, 189, 118, 122]
# Tracking done in step: 11946
# pre_loc [238, 196, 119, 104]
# Tracking done in step: 11947
# pre_loc [243, 205, 118, 107]
# Tracking done in step: 11948
# pre_loc [241, 206, 126, 111]
# Tracking done in step: 11949
# pre_loc [255, 203, 166, 110]
# Tracking done in step: 11950
# pre_loc [232, 207, 158, 138]
# Tracking done in step: 11951
# pre_loc [216, 192, 112, 123]
# Tracking done in step: 11952
# pre_loc [256, 228, 210, 198]
# Tracking done in step: 11953
# pre_loc [231, 190, 217, 201]
# Tracking done in step: 11954
# pre_loc [240, 182, 198, 179]
# Tracking done in step: 11955
# pre_loc [252, 178, 196, 156]
# Tracking done in step: 11956
# pre_loc [264, 185, 185, 155]
# Tracking done in step: 11957
# pre_loc [277, 186, 183, 138]
# Tracking done in step: 11958
# pre_loc [283, 199, 179, 140]
# Tracking done in step: 11959
# pre_loc [291, 193, 177, 131]
# Tracking done in step: 11960
# pre_loc [330, 210, 173, 161]
# Tracking done in step: 11961
# pre_loc [343, 183, 146, 127]
# Tracking done in step: 11962
# pre_loc [374, 228, 167, 204]
# Tracking done in step: 11963
# pre_loc [367, 175, 209, 218]
# Tracking done in step: 11964
# pre_loc [358, 168, 162, 206]
# Tracking done in step: 11965
# pre_loc [409, 182, 222, 217]
# Tracking done in step: 11966
# pre_loc [390, 163, 205, 215]
# Tracking done in step: 11967
# pre_loc [404, 179, 210, 201]
# Tracking done in step: 11968
# pre_loc [387, 153, 168, 98]
# Tracking done in step: 11969
# pre_loc [447, 299, 161, 67]
# Tracking done in step: 11970
# pre_loc [476, 309, 116, 111]
# Tracking done in step: 11971
# pre_loc [458, 286, 223, 211]
# Tracking done in step: 11972
# ---------------------------------------
# ValueErrorTraceback (most recent call last)
# <ipython-input-5-a92ca9bc3aaf> in <module>()
#      96
#      97         pre_M = tracker.preporcess_heatmaps(pre_M_g, pre_M_s, resize=(224,224))
# ---> 98         pre_loc = tracker.predict_location(pre_M,gt_last,rz_factor,threshold=np.arange(0.3, 0.9, 0.05))
#      99
#     100         gt_last = pre_loc
#
# /home/xlws/repos/FCNT_bak/tracker.py in predict_location(self, pre_M, gt_last, rz_factor, threshold)
#      94                     bbox_list += [(x,y,w,h)]
#      95                     arear_list += [cv2.contourArea(cnt)]
# ---> 96             pre_loc_roi, idx, conf_score = self._compute_score(bbox_list, arear_list)
#      97             self.conf_scores += [conf_score]
#      98
#
# /home/xlws/repos/FCNT_bak/tracker.py in _compute_score(self, loc_list, arear_list)
#      31         for loc in loc_list:
#      32             scores_dis += [sum([abs(x-x0) for x,x0 in zip(loc,self.last_pre_loc_roi)])]
# ---> 33         scores_dis = np.array(scores_dis) / max(scores_dis)
#      34         arear_list = np.array(arear_list)/ max(arear_list)
#      35         scores = scores_dis / arear_list
#
# ValueError: max() arg is an empty sequence

# %%
gt

# %%
img.shape

# %%
inputProducer.extract_roi(img, gt)

# %%
cap = cv2.VideoCapture(0)

# %%
ret, img = cap.read()

ret

# %%
cv2.imshow("pre_M", pre_M)

# %%
str(img.shape)

# %%
refPt_2_gt(refPt)

# %%
image.shape
